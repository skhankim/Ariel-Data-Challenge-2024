# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats
from tqdm import tqdm

from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_squared_error
import torch
import torch.nn as nn
import torch.nn.functional as F
from fastprogress import master_bar, progress_bar
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import transforms
import torchvision.models as models
from torchvision.models.efficientnet import _efficientnet_conf, _efficientnet
from functools import partial
import random, os
import itertools
from astropy.stats import sigma_clip
def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
seed_everything(42)

# %% [markdown]
# ## Metric

# %%
class ParticipantVisibleError(Exception):
    pass
def ariel_score(
        solution,
        submission,
        naive_mean,
        naive_sigma,
        sigma_true
    ):
    '''
    This is a Gaussian Log Likelihood based metric. For a submission, which contains the predicted mean (x_hat) and variance (x_hat_std),
    we calculate the Gaussian Log-likelihood (GLL) value to the provided ground truth (x). We treat each pair of x_hat,
    x_hat_std as a 1D gaussian, meaning there will be 283 1D gaussian distributions, hence 283 values for each test spectrum,
    the GLL value for one spectrum is the sum of all of them.

    Inputs:
        - solution: Ground Truth spectra (from test set)
            - shape: (nsamples, n_wavelengths)
        - submission: Predicted spectra and errors (from participants)
            - shape: (nsamples, n_wavelengths*2)
        naive_mean: (float) mean from the train set.
        naive_sigma: (float) standard deviation from the train set.
        sigma_true: (float) essentially sets the scale of the outputs.
    '''

    if submission.min() < 0:
        raise ParticipantVisibleError('Negative values in the submission')

    n_wavelengths = 283

    y_pred = submission[:, :n_wavelengths]
    # Set a non-zero minimum sigma pred to prevent division by zero errors.
    sigma_pred = np.clip(submission[:, n_wavelengths:], a_min=10**-15, a_max=None)
    y_true = solution

    GLL_pred = np.sum(scipy.stats.norm.logpdf(y_true, loc=y_pred, scale=sigma_pred))
    GLL_true = np.sum(scipy.stats.norm.logpdf(y_true, loc=y_true, scale=sigma_true * np.ones_like(y_true)))
    GLL_mean = np.sum(scipy.stats.norm.logpdf(y_true, loc=naive_mean * np.ones_like(y_true), scale=naive_sigma * np.ones_like(y_true)))

    #print(GLL_pred, GLL_true, GLL_mean)
    submit_score = (GLL_pred - GLL_mean)/(GLL_true - GLL_mean)
    return submit_score #float(np.clip(submit_score, 0.0, 1.0))

# %% [markdown]
# ## Raw data binned 15 time measurements
#
# Unfortunately, I have lost the exact code that I received the dataset with, I really hope that it matches the one in the inference notebook.

# %%
train_adc_info = pd.read_csv('/kaggle/input/ariel-data-challenge-2024/train_adc_info.csv',
                           index_col='planet_id')
train_labels = pd.read_csv('/kaggle/input/ariel-data-challenge-2024/train_labels.csv',
                           index_col='planet_id')
# train_AIRS = np.load('/kaggle/input/adc-preprocced-signal-data/train_AIRS_preproc.csv.npy')
# train_FGS = np.load('/kaggle/input/adc-preprocced-signal-data/train_FGS1_preproc.csv.npy')
# pre_train = np.concatenate([train_FGS, train_AIRS], axis=2)
pre_train = np.load('/kaggle/input/preproceesed-data-375/pre_train_375.npy')
pre_test = np.load('/kaggle/input/preproceesed-data-375/pre_test_375.npy')
test_adc_info = pd.read_csv('/kaggle/input/ariel-data-challenge-2024/test_adc_info.csv',
                           index_col='planet_id')
axis_info = pd.read_parquet('/kaggle/input/ariel-data-challenge-2024/axis_info.parquet')

# %%
pre_train.shape
# Out:
# (673, 375, 283)

# %% [markdown]
# ## Transit phase detector
#
# A simple algorithm for finding points where there is a rapid drop in luminosity

# %% [markdown]
# ## Dataset
# We will use (flux - flux_transit) / flux_star as features. If we didn't have a distortion of the star's light, then our targets would be exactly among these signs.

# %%
def phase_detector(signal):
    phase1, phase2 = None, None
    best_drop = 0
    for i in range(50,150):        
        t1 = signal[i:i+20].max() - signal[i:i+20].min()
        if t1 > best_drop:
            phase1 = i+20+5
            best_drop = t1
    
    best_drop = 0
    for i in range(200,300):
        t1 = signal[i:i+20].max() - signal[i:i+20].min()
        if t1 > best_drop:
            phase2 = i-5
            best_drop = t1
    
    return phase1, phase2

# %%
train = pre_train.copy()
for i in range(len(train_adc_info)):
    p1,p2 = phase_detector(pre_train[i,:,1:].mean(axis=1))
    train[i] = (train[i] - pre_train[i,p1:p2].mean(axis=0)) / pre_train[i,list(range(p1-40)) + list(range(p2+40,375))].mean(axis=0) * 1000.0

# %%
n = 205
plt.plot(pre_train[n,:,1:].mean(axis=1))
p1, p2 = phase_detector(pre_train[n,:,1:].mean(axis=1))
plt.axvline(p1)
plt.axvline(p2)
plt.axvline(p1-40)
plt.axvline(p2+40)

# %%
train.mean(), train.std()
# Out:
# (1.6391348407613593, 2.8748483317598192)

# %% [markdown]
# ## Model
# As a model, I use MobileNet_v2 as the least overfitting. Initially, it accepts a 3-channel image as input, so I added a layer that converts the input into a three-channel one.
#
# The output has 3 numbers for each wavelength corresponding to 0.1587,0.5,0.8413 percentiles.

# %%
def create_model_mnet2():
    model = models.mobilenet_v3_small(dropout=0.0, norm_layer = nn.Identity) # batch norm을 모두 indentity 하게 바꿔버림-> batch norm에서 수행하는 바이어스 보정이 사라짐->bias=True로 바꿀 필요성 생김
    model.features[0][0] = nn.Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)# 모델 가중치 초기화를 위해 bias=False로 설정해서 레이어 재설정한건가? 왜 bias = False로 한지 모르겟음
    model.classifier[3] = nn.Linear(in_features=1024, out_features=283*3, bias=True) # 최종 output 283 * 3
    return model

class ImpModel(torch.nn.Module):
    def __init__(self):
        super(ImpModel, self).__init__()

        self.filter = nn.Sequential(
            nn.Conv2d(1, 3, kernel_size=(3,1), stride = (2,1), bias=False),
            nn.LeakyReLU()
        )
        self.model_1d = create_model_mnet2()
        
    def forward(self, x):
        x = self.filter(x)
        x = self.model_1d(x)
        return x

# %% [markdown]
# ## Loss
# This loss function predicts not only the value itself, but also its two percentiles. With their help, assuming that the error is distributed normally, we can get an estimate of the standard deviation.
#
# https://www.kaggle.com/code/vyacheslavefimov/quantile-loss-quantile-regression

# %% [markdown]
# quantile을 설정해 과대예측, 과소예측 경향성을 예측 모델에 추가하여 uncertainty를 좀 더 정확하게 예측하고자 하기 위함인듯

# %%
def q_loss(quantiles, y_pred, target):
    losses = []
    for i, q in enumerate(quantiles):        
        errors = target - y_pred[..., i]
        losses.append(torch.max((q - 1) * errors, q * errors).unsqueeze(-1))#
    losses = 2 * torch.cat(losses, dim=2)

    return losses

# %%
# train_sample = train.copy()
# planet_data = train_sample[0].reshape(1,375,283)
# planet_target = train_labels.loc[785834].values
# test_tensor, planet_target = torch.tensor(planet_data, dtype=torch.float32).unsqueeze(1), torch.tensor(planet_target, dtype=torch.float32).unsqueeze(1)  
# test_tensor, planet_target = test_tensor.to(device), planet_target.to(device)
# with torch.no_grad(): 
#     model.eval()
#     pred = model(test_tensor)
# output_a = pred[:,1::3] # differ to quantile 0, 1, 2

# %%
# a=q_loss([0.1587, 0.5, 0.8413], pred, planet_target)
# a.shape

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=5)
X = list(range(len(train)))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

oof_pred = np.zeros_like(train_labels.values)
oof_sigmas = np.zeros_like(train_labels.values)

for ifold, (train_index, test_index) in enumerate(kf.split(X)):
   
    train_x = torch.from_numpy(train[train_index]).unsqueeze(1).float().to(device)
    train_y = torch.from_numpy(train_labels.values[train_index]).float().to(device)
    train_dataset = torch.utils.data.TensorDataset(train_x, train_y)
    training_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)

    val_x = torch.from_numpy(train[test_index]).unsqueeze(1).float().to(device)
    val_y = torch.from_numpy(train_labels.values[test_index]).float().to(device)
    val_dataset = torch.utils.data.TensorDataset(val_x, val_y)
    validation_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False)
    
    model = ImpModel().to(device)

    best_metric = 0
    total_train_losses = []

    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 200, eta_min=0, last_epoch=-1)
    for epoch in range(200):
        ep_losses = []        
        model.train()
        for i, data in enumerate(training_loader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device) 
            
            optimizer.zero_grad()

            # augmentations: disturb channel and reverse the time
            if epoch > 0:
                for j in range(inputs.shape[-1]):
                    if np.random.random() > 0.8:
                        inputs[...,j] = inputs[...,j] * (1 + np.random.randn() * 0.01)
                for k in range(inputs.shape[0]):
                    if np.random.random() > 0.8:
                        inputs[k] = torch.flip(inputs[k], (1,))

            outputs = model(inputs).reshape((inputs.shape[0], 283, 3))

            loss = q_loss([0.1587, 0.5, 0.8413], outputs, labels).mean()
            loss.backward()

            optimizer.step()

            ep_losses.append(loss.item())

        avg_loss = np.mean(ep_losses)
        total_train_losses.append(avg_loss)

        model.eval()
        running_vloss = 0
        preds = np.zeros((len(val_dataset), 283))
        sigmas = np.zeros((len(val_dataset), 283))
        v_offset = 0
        with torch.no_grad():        
            for i, vdata in enumerate(validation_loader):
                vinputs, vlabels = vdata
                vinputs, vlabels = vinputs.to(device), vlabels.to(device) 
                
                voutputs = model(vinputs).reshape((vinputs.shape[0], 283, 3))
                preds[v_offset:v_offset+len(vinputs)] = voutputs[:, :, 1].detach().cpu().numpy()
                sigmas[v_offset:v_offset+len(vinputs)] = voutputs[:, :, 2].detach().cpu().numpy() - voutputs[:, :, 0].detach().cpu().numpy()
                vloss = q_loss([0.1587, 0.5, 0.8413], voutputs, vlabels).mean()
                running_vloss += vloss
                v_offset += len(vinputs)

        avg_vloss = running_vloss / (i + 1)

        metric = ariel_score(
            train_labels.values[test_index],
            np.concatenate([preds.clip(0), sigmas.clip(0)], axis=1), 
            train_labels.values[test_index].mean(),
            train_labels.values[test_index].std(),
            sigma_true=1e-5
        )
        
        print('fold {} epoch {} train {} valid {} metric {}'.format(
            ifold, epoch, round(avg_loss*100, 3), round(avg_vloss.item()*100, 3), round(metric, 3)
        ))
        
        scheduler.step()
        
    oof_pred[test_index] = preds
    oof_sigmas[test_index] = sigmas
    torch.save(model.state_dict(), 'purple_hat_{}'.format(ifold))
# Out:
# fold 0 epoch 0 train 0.363 valid 0.112 metric -0.119
# fold 0 epoch 1 train 0.11 valid 0.095 metric -0.081
# fold 0 epoch 2 train 0.104 valid 0.097 metric -0.069
# fold 0 epoch 3 train 0.107 valid 0.094 metric -0.057
# fold 0 epoch 4 train 0.104 valid 0.095 metric -0.105
# fold 0 epoch 5 train 0.102 valid 0.094 metric -0.088
# fold 0 epoch 6 train 0.104 valid 0.097 metric -0.112
# fold 0 epoch 7 train 0.104 valid 0.1 metric -0.087
# fold 0 epoch 8 train 0.104 valid 0.094 metric -0.092
# fold 0 epoch 9 train 0.104 valid 0.093 metric -0.048
# fold 0 epoch 10 train 0.104 valid 0.095 metric -0.073
# fold 0 epoch 11 train 0.105 valid 0.101 metric -0.092
# fold 0 epoch 12 train 0.103 valid 0.094 metric -0.099
# fold 0 epoch 13 train 0.104 valid 0.103 metric -0.095
# fold 0 epoch 14 train 0.104 valid 0.057 metric -6.644760228195513e+20
# fold 0 epoch 15 train 0.048 valid 0.047 metric -2.5502937273433897e+21
# fold 0 epoch 16 train 0.036 valid 0.029 metric -5.601919548192701e+19
# fold 0 epoch 17 train 0.037 valid 0.028 metric -1.6499982705952853e+20
# fold 0 epoch 18 train 0.026 valid 0.043 metric -3.109765534796677e+21
# fold 0 epoch 19 train 0.032 valid 0.032 metric -3.898188736886434e+20
# fold 0 epoch 20 train 0.025 valid 0.023 metric -1.2552897238766204e+20
# fold 0 epoch 21 train 0.027 valid 0.024 metric -1.783405175002857e+20
# fold 0 epoch 22 train 0.024 valid 0.017 metric -9.464473604761892e+19
# fold 0 epoch 23 train 0.02 valid 0.017 metric -8.960115032092759e+19
# fold 0 epoch 24 train 0.023 valid 0.017 metric -2.189919274522896e+20
# fold 0 epoch 25 train 0.021 valid 0.019 metric -9.572850172115539e+19
# fold 0 epoch 26 train 0.021 valid 0.031 metric -5.74640563916633e+20
# fold 0 epoch 27 train 0.02 valid 0.019 metric -1.2648533727031337e+20
# fold 0 epoch 28 train 0.022 valid 0.022 metric -2.4173222118468026e+20
# fold 0 epoch 29 train 0.021 valid 0.022 metric -1.0343440258636766e+20
# fold 0 epoch 30 train 0.02 valid 0.02 metric -4.07484206773525e+19
# fold 0 epoch 31 train 0.018 valid 0.025 metric -7.105152866484539e+19
# fold 0 epoch 32 train 0.022 valid 0.016 metric -1.2415949577629786e+20
# fold 0 epoch 33 train 0.017 valid 0.016 metric -1.4056483301087856e+20
# fold 0 epoch 34 train 0.019 valid 0.017 metric -4.42231473019949e+19
# fold 0 epoch 35 train 0.017 valid 0.014 metric -1.4578805122997212e+20
# fold 0 epoch 36 train 0.015 valid 0.019 metric -4.843500301162877e+20
# fold 0 epoch 37 train 0.018 valid 0.016 metric -1.555866273954571e+20
# fold 0 epoch 38 train 0.015 valid 0.013 metric -3.738467240104254e+19
# fold 0 epoch 39 train 0.013 valid 0.013 metric -1.0789567874772966e+20
# fold 0 epoch 40 train 0.012 valid 0.011 metric -1.0908787796574996e+20
# fold 0 epoch 41 train 0.013 valid 0.014 metric -8.71143499743919e+19
# fold 0 epoch 42 train 0.012 valid 0.011 metric -4.077327264722766e+19
# fold 0 epoch 43 train 0.013 valid 0.011 metric -7.441723221823672e+19
# fold 0 epoch 44 train 0.012 valid 0.011 metric -9.592957847712108e+19
# fold 0 epoch 45 train 0.012 valid 0.012 metric -1.1569520405881479e+20
# fold 0 epoch 46 train 0.016 valid 0.015 metric -1.6156201085938608e+20
# fold 0 epoch 47 train 0.013 valid 0.012 metric -8.438426009747751e+19
# fold 0 epoch 48 train 0.012 valid 0.013 metric -1.1783559862709866e+20
# fold 0 epoch 49 train 0.011 valid 0.01 metric -1.745863771873192e+20
# fold 0 epoch 50 train 0.01 valid 0.013 metric -2.488358820312371e+20
# fold 0 epoch 51 train 0.012 valid 0.011 metric -1.670618258730828e+20
# fold 0 epoch 52 train 0.011 valid 0.01 metric -7.420053652199381e+19
# fold 0 epoch 53 train 0.011 valid 0.014 metric -1.514562859170401e+20
# fold 0 epoch 54 train 0.012 valid 0.011 metric -8.131398453330194e+19
# fold 0 epoch 55 train 0.01 valid 0.011 metric -7.73806324153668e+19
# fold 0 epoch 56 train 0.011 valid 0.012 metric -1.0816361239680356e+20
# fold 0 epoch 57 train 0.011 valid 0.013 metric -4.491292410128576e+19
# fold 0 epoch 58 train 0.011 valid 0.012 metric -1.331493592257215e+20
# fold 0 epoch 59 train 0.013 valid 0.012 metric -9.714822029605066e+19
# fold 0 epoch 60 train 0.011 valid 0.009 metric -4.640609731978412e+19
# fold 0 epoch 61 train 0.01 valid 0.011 metric -2.035782234449969e+20
# fold 0 epoch 62 train 0.012 valid 0.014 metric -8.049245217828518e+19
# fold 0 epoch 63 train 0.01 valid 0.009 metric -6.971668121086983e+19
# fold 0 epoch 64 train 0.009 valid 0.009 metric -3.822069842202573e+19
# fold 0 epoch 65 train 0.011 valid 0.012 metric -1.3545859691057014e+20
# fold 0 epoch 66 train 0.009 valid 0.009 metric -3.374725733894053e+19
# fold 0 epoch 67 train 0.009 valid 0.014 metric -5.160278754398712e+19
# fold 0 epoch 68 train 0.011 valid 0.011 metric -4.258554638205859e+19
# fold 0 epoch 69 train 0.01 valid 0.01 metric -3.1734937018652918e+19
# fold 0 epoch 70 train 0.01 valid 0.01 metric -4.165927742070022e+19
# fold 0 epoch 71 train 0.01 valid 0.011 metric -1.2901695749129036e+20
# fold 0 epoch 72 train 0.01 valid 0.009 metric -6.739167510137294e+19
# fold 0 epoch 73 train 0.009 valid 0.014 metric -1.920903797535568e+20
# fold 0 epoch 74 train 0.009 valid 0.009 metric -8.19295482827748e+19
# fold 0 epoch 75 train 0.009 valid 0.01 metric -7.844000158480371e+19
# fold 0 epoch 76 train 0.009 valid 0.011 metric -5.91304987598776e+19
# fold 0 epoch 77 train 0.01 valid 0.009 metric -4.669248360057332e+19
# fold 0 epoch 78 train 0.009 valid 0.008 metric -8.203578518280774e+19
# fold 0 epoch 79 train 0.008 valid 0.009 metric -4.950340629627602e+19
# fold 0 epoch 80 train 0.008 valid 0.008 metric -4.3331812537521775e+19
# fold 0 epoch 81 train 0.009 valid 0.009 metric -7.494048899191043e+19
# fold 0 epoch 82 train 0.008 valid 0.009 metric -4.5974824202475766e+19
# fold 0 epoch 83 train 0.009 valid 0.01 metric -7.2428253214961885e+19
# fold 0 epoch 84 train 0.008 valid 0.009 metric -5.783176738074051e+19
# fold 0 epoch 85 train 0.009 valid 0.01 metric -3.830592949021832e+19
# fold 0 epoch 86 train 0.008 valid 0.008 metric -1.010256281520374e+20
# fold 0 epoch 87 train 0.007 valid 0.007 metric -6.5634081201440416e+19
# fold 0 epoch 88 train 0.007 valid 0.009 metric -1.3830930626503784e+19
# fold 0 epoch 89 train 0.009 valid 0.009 metric -4.981548742018534e+19
# fold 0 epoch 90 train 0.009 valid 0.008 metric -1.2259678102167763e+19
# fold 0 epoch 91 train 0.007 valid 0.008 metric -1.99893276087543e+19
# fold 0 epoch 92 train 0.007 valid 0.007 metric -1.5464950222355354e+19
# fold 0 epoch 93 train 0.008 valid 0.007 metric -1.4624693057823896e+19
# fold 0 epoch 94 train 0.007 valid 0.007 metric -3.443903763953697e+19
# fold 0 epoch 95 train 0.007 valid 0.007 metric -1.8640053239396205e+19
# fold 0 epoch 96 train 0.008 valid 0.009 metric -1.479448158790495e+19
# fold 0 epoch 97 train 0.007 valid 0.009 metric -3.478113388547546e+19
# fold 0 epoch 98 train 0.007 valid 0.008 metric -7.387670953827921e+19
# fold 0 epoch 99 train 0.007 valid 0.008 metric -3.3562507750448513e+19
# fold 0 epoch 100 train 0.008 valid 0.008 metric -4.756109779059605e+19
# fold 0 epoch 101 train 0.007 valid 0.008 metric -1.6538022190820477e+19
# fold 0 epoch 102 train 0.007 valid 0.007 metric -3.791816282843389e+19
# fold 0 epoch 103 train 0.007 valid 0.007 metric -2.4598759067247636e+19
# fold 0 epoch 104 train 0.007 valid 0.008 metric -3.3782000534621557e+19
# fold 0 epoch 105 train 0.007 valid 0.007 metric -3.084890450096595e+19
# fold 0 epoch 106 train 0.007 valid 0.009 metric -2.7123835413775925e+19
# fold 0 epoch 107 train 0.007 valid 0.008 metric -4.4275086414431503e+18
# fold 0 epoch 108 train 0.007 valid 0.007 metric -1.123768450780118e+19
# fold 0 epoch 109 train 0.007 valid 0.007 metric -1.1069358928273015e+19
# fold 0 epoch 110 train 0.007 valid 0.007 metric -2.8897594228312388e+19
# fold 0 epoch 111 train 0.007 valid 0.006 metric -1.243843568339772e+19
# fold 0 epoch 112 train 0.006 valid 0.006 metric -8.457959051627243e+19
# fold 0 epoch 113 train 0.006 valid 0.007 metric -8.372504997506015e+18
# fold 0 epoch 114 train 0.006 valid 0.006 metric -7.658430877625072e+18
# fold 0 epoch 115 train 0.006 valid 0.006 metric -5.501801479270934e+19
# fold 0 epoch 116 train 0.006 valid 0.006 metric -1.0806372880165775e+19
# fold 0 epoch 117 train 0.006 valid 0.006 metric -1.338574433041855e+19
# fold 0 epoch 118 train 0.006 valid 0.006 metric -1.4337849409554395e+19
# fold 0 epoch 119 train 0.006 valid 0.006 metric -4.110069465746008e+19
# fold 0 epoch 120 train 0.006 valid 0.007 metric -7.18289026218693e+18
# fold 0 epoch 121 train 0.006 valid 0.007 metric -2.8902889514933457e+19
# fold 0 epoch 122 train 0.006 valid 0.006 metric -2.1843592498706113e+19
# fold 0 epoch 123 train 0.005 valid 0.006 metric -1.92210411582652e+19
# fold 0 epoch 124 train 0.005 valid 0.006 metric -4.926825277671234e+18
# fold 0 epoch 125 train 0.006 valid 0.006 metric -8.218508132390989e+18
# fold 0 epoch 126 train 0.006 valid 0.006 metric -1.121493965792127e+19
# fold 0 epoch 127 train 0.005 valid 0.006 metric -7.927515923711089e+17
# fold 0 epoch 128 train 0.005 valid 0.008 metric -8.92665135764027e+18
# fold 0 epoch 129 train 0.006 valid 0.007 metric -2.565699143348733e+19
# fold 0 epoch 130 train 0.006 valid 0.005 metric -9.963021998067297e+17
# fold 0 epoch 131 train 0.005 valid 0.006 metric -9.986290563729038e+17
# fold 0 epoch 132 train 0.005 valid 0.005 metric -6.43270591258919e+18
# fold 0 epoch 133 train 0.005 valid 0.006 metric -3.1604233939505684e+18
# fold 0 epoch 134 train 0.005 valid 0.006 metric -1.7932408328393472e+18
# fold 0 epoch 135 train 0.005 valid 0.005 metric 0.452
# fold 0 epoch 136 train 0.005 valid 0.006 metric -2.1633945744344654e+19
# fold 0 epoch 137 train 0.005 valid 0.005 metric -2.6678847521697142e+17
# fold 0 epoch 138 train 0.005 valid 0.005 metric -1.355609738395286e+19
# fold 0 epoch 139 train 0.005 valid 0.005 metric -9.539949608740585e+18
# fold 0 epoch 140 train 0.005 valid 0.005 metric -2.966638968611549e+18
# fold 0 epoch 141 train 0.005 valid 0.005 metric -1.7297836442180685e+17
# fold 0 epoch 142 train 0.005 valid 0.006 metric 0.41
# fold 0 epoch 143 train 0.005 valid 0.005 metric -2.870250071975834e+18
# fold 0 epoch 144 train 0.005 valid 0.005 metric 0.416
# fold 0 epoch 145 train 0.005 valid 0.005 metric -8.21888453803132e+17
# fold 0 epoch 146 train 0.005 valid 0.005 metric -3.904579962004647e+17
# fold 0 epoch 147 train 0.005 valid 0.005 metric -3.1020605266598026e+18
# fold 0 epoch 148 train 0.004 valid 0.005 metric 0.473
# fold 0 epoch 149 train 0.005 valid 0.006 metric 0.411
# fold 0 epoch 150 train 0.005 valid 0.005 metric -3.405207892800777e+17
# fold 0 epoch 151 train 0.004 valid 0.005 metric 0.459
# fold 0 epoch 152 train 0.004 valid 0.005 metric 0.48
# fold 0 epoch 153 train 0.005 valid 0.005 metric -9.345760030794206e+16
# fold 0 epoch 154 train 0.004 valid 0.005 metric -1.3706134692162312e+18
# fold 0 epoch 155 train 0.004 valid 0.005 metric -1.6179057278445956e+16
# fold 0 epoch 156 train 0.004 valid 0.005 metric 0.483
# fold 0 epoch 157 train 0.004 valid 0.005 metric 0.496
# fold 0 epoch 158 train 0.004 valid 0.005 metric 0.479
# fold 0 epoch 159 train 0.004 valid 0.005 metric -1.9569074294145872e+17
# fold 0 epoch 160 train 0.004 valid 0.005 metric 0.493
# fold 0 epoch 161 train 0.004 valid 0.005 metric 0.485
# fold 0 epoch 162 train 0.004 valid 0.005 metric 0.48
# fold 0 epoch 163 train 0.004 valid 0.005 metric 0.475
# fold 0 epoch 164 train 0.004 valid 0.005 metric 0.463
# fold 0 epoch 165 train 0.004 valid 0.005 metric 0.488
# fold 0 epoch 166 train 0.004 valid 0.005 metric 0.499
# fold 0 epoch 167 train 0.004 valid 0.005 metric 0.494
# fold 0 epoch 168 train 0.004 valid 0.004 metric 0.498
# fold 0 epoch 169 train 0.004 valid 0.004 metric 0.506
# fold 0 epoch 170 train 0.004 valid 0.005 metric 0.512
# fold 0 epoch 171 train 0.004 valid 0.004 metric 0.507
# fold 0 epoch 172 train 0.004 valid 0.005 metric 0.507
# fold 0 epoch 173 train 0.004 valid 0.005 metric 0.504
# fold 0 epoch 174 train 0.004 valid 0.005 metric 0.504
# fold 0 epoch 175 train 0.004 valid 0.004 metric 0.512
# fold 0 epoch 176 train 0.004 valid 0.004 metric 0.508
# fold 0 epoch 177 train 0.004 valid 0.004 metric 0.516
# fold 0 epoch 178 train 0.004 valid 0.005 metric 0.491
# fold 0 epoch 179 train 0.004 valid 0.004 metric 0.507
# fold 0 epoch 180 train 0.004 valid 0.004 metric 0.522
# fold 0 epoch 181 train 0.004 valid 0.004 metric 0.507
# fold 0 epoch 182 train 0.004 valid 0.004 metric 0.511
# fold 0 epoch 183 train 0.004 valid 0.004 metric 0.516
# fold 0 epoch 184 train 0.004 valid 0.004 metric 0.514
# fold 0 epoch 185 train 0.004 valid 0.004 metric 0.517
# fold 0 epoch 186 train 0.004 valid 0.004 metric 0.517
# fold 0 epoch 187 train 0.004 valid 0.004 metric 0.518
# fold 0 epoch 188 train 0.004 valid 0.004 metric 0.516
# fold 0 epoch 189 train 0.004 valid 0.004 metric 0.518
# fold 0 epoch 190 train 0.004 valid 0.004 metric 0.521
# fold 0 epoch 191 train 0.004 valid 0.004 metric 0.522
# fold 0 epoch 192 train 0.004 valid 0.004 metric 0.519
# fold 0 epoch 193 train 0.004 valid 0.004 metric 0.52
# fold 0 epoch 194 train 0.004 valid 0.004 metric 0.52
# fold 0 epoch 195 train 0.004 valid 0.004 metric 0.522
# fold 0 epoch 196 train 0.004 valid 0.004 metric 0.521
# fold 0 epoch 197 train 0.004 valid 0.004 metric 0.521
# fold 0 epoch 198 train 0.004 valid 0.004 metric 0.521
# fold 0 epoch 199 train 0.004 valid 0.004 metric 0.521
# fold 1 epoch 0 train 0.387 valid 0.114 metric -0.124
# fold 1 epoch 1 train 0.11 valid 0.098 metric -0.068
# fold 1 epoch 2 train 0.105 valid 0.098 metric -0.078
# fold 1 epoch 3 train 0.104 valid 0.094 metric -0.074
# fold 1 epoch 4 train 0.106 valid 0.095 metric -0.081
# fold 1 epoch 5 train 0.103 valid 0.104 metric -0.082
# fold 1 epoch 6 train 0.103 valid 0.103 metric -0.029
# fold 1 epoch 7 train 0.107 valid 0.103 metric -0.109
# fold 1 epoch 8 train 0.107 valid 0.108 metric -0.084
# fold 1 epoch 9 train 0.104 valid 0.105 metric -0.111
# fold 1 epoch 10 train 0.106 valid 0.106 metric -0.056
# fold 1 epoch 11 train 0.104 valid 0.099 metric -0.107
# fold 1 epoch 12 train 0.104 valid 0.098 metric -0.088
# fold 1 epoch 13 train 0.102 valid 0.095 metric -0.039
# fold 1 epoch 14 train 0.102 valid 0.096 metric -0.1
# fold 1 epoch 15 train 0.105 valid 0.094 metric -0.07
# fold 1 epoch 16 train 0.104 valid 0.099 metric -0.098
# fold 1 epoch 17 train 0.104 valid 0.101 metric -0.078
# fold 1 epoch 18 train 0.105 valid 0.105 metric -0.064
# fold 1 epoch 19 train 0.105 valid 0.094 metric -0.083
# fold 1 epoch 20 train 0.103 valid 0.105 metric -0.099
# fold 1 epoch 21 train 0.103 valid 0.094 metric -0.082
# fold 1 epoch 22 train 0.102 valid 0.093 metric -0.082
# fold 1 epoch 23 train 0.102 valid 0.096 metric -0.106
# fold 1 epoch 24 train 0.107 valid 0.101 metric -0.094
# fold 1 epoch 25 train 0.108 valid 0.104 metric -0.077
# fold 1 epoch 26 train 0.102 valid 0.096 metric -0.072
# fold 1 epoch 27 train 0.102 valid 0.094 metric -0.08
# fold 1 epoch 28 train 0.102 valid 0.1 metric -0.091
# fold 1 epoch 29 train 0.105 valid 0.097 metric -0.07
# fold 1 epoch 30 train 0.104 valid 0.098 metric -0.081
# fold 1 epoch 31 train 0.103 valid 0.094 metric -0.088
# fold 1 epoch 32 train 0.104 valid 0.097 metric -0.059
# fold 1 epoch 33 train 0.107 valid 0.1 metric -0.067
# fold 1 epoch 34 train 0.101 valid 0.096 metric -0.078
# fold 1 epoch 35 train 0.102 valid 0.096 metric -0.084
# fold 1 epoch 36 train 0.101 valid 0.094 metric -0.049
# fold 1 epoch 37 train 0.104 valid 0.094 metric -0.082
# fold 1 epoch 38 train 0.102 valid 0.099 metric -0.084
# fold 1 epoch 39 train 0.102 valid 0.093 metric -0.048
# fold 1 epoch 40 train 0.103 valid 0.093 metric -0.079
# fold 1 epoch 41 train 0.103 valid 0.092 metric -0.069
# fold 1 epoch 42 train 0.101 valid 0.095 metric -0.065
# fold 1 epoch 43 train 0.102 valid 0.094 metric -0.09
# fold 1 epoch 44 train 0.101 valid 0.096 metric -0.028
# fold 1 epoch 45 train 0.103 valid 0.097 metric -0.097
# fold 1 epoch 46 train 0.103 valid 0.094 metric -0.092
# fold 1 epoch 47 train 0.102 valid 0.097 metric -0.088
# fold 1 epoch 48 train 0.101 valid 0.093 metric -0.074
# fold 1 epoch 49 train 0.102 valid 0.095 metric -0.06
# fold 1 epoch 50 train 0.102 valid 0.097 metric -0.101
# fold 1 epoch 51 train 0.108 valid 0.107 metric -0.091
# fold 1 epoch 52 train 0.105 valid 0.101 metric -0.091
# fold 1 epoch 53 train 0.103 valid 0.098 metric -0.113
# fold 1 epoch 54 train 0.102 valid 0.099 metric -0.052
# fold 1 epoch 55 train 0.102 valid 0.096 metric -0.069
# fold 1 epoch 56 train 0.102 valid 0.1 metric -0.062
# fold 1 epoch 57 train 0.104 valid 0.097 metric -0.061
# fold 1 epoch 58 train 0.102 valid 0.095 metric -0.097
# fold 1 epoch 59 train 0.101 valid 0.094 metric -0.086
# fold 1 epoch 60 train 0.103 valid 0.094 metric -0.07
# fold 1 epoch 61 train 0.103 valid 0.103 metric -0.052
# fold 1 epoch 62 train 0.103 valid 0.1 metric -0.1
# fold 1 epoch 63 train 0.103 valid 0.094 metric -0.075
# fold 1 epoch 64 train 0.104 valid 0.099 metric -0.11
# fold 1 epoch 65 train 0.102 valid 0.098 metric -0.103
# fold 1 epoch 66 train 0.101 valid 0.094 metric -0.077
# fold 1 epoch 67 train 0.101 valid 0.099 metric -0.084
# fold 1 epoch 68 train 0.101 valid 0.094 metric -0.095
# fold 1 epoch 69 train 0.102 valid 0.098 metric -0.067
# fold 1 epoch 70 train 0.102 valid 0.096 metric -0.101
# fold 1 epoch 71 train 0.1 valid 0.099 metric -0.097
# fold 1 epoch 72 train 0.104 valid 0.1 metric -0.074
# fold 1 epoch 73 train 0.101 valid 0.093 metric -0.078
# fold 1 epoch 74 train 0.102 valid 0.095 metric -0.064
# fold 1 epoch 75 train 0.103 valid 0.096 metric -0.045
# fold 1 epoch 76 train 0.103 valid 0.102 metric -0.123
# fold 1 epoch 77 train 0.102 valid 0.094 metric -0.066
# fold 1 epoch 78 train 0.101 valid 0.094 metric -0.075
# fold 1 epoch 79 train 0.102 valid 0.096 metric -0.066
# fold 1 epoch 80 train 0.103 valid 0.104 metric -0.12
# fold 1 epoch 81 train 0.102 valid 0.095 metric -0.074
# fold 1 epoch 82 train 0.102 valid 0.094 metric -0.061
# fold 1 epoch 83 train 0.101 valid 0.094 metric -0.054
# fold 1 epoch 84 train 0.102 valid 0.097 metric -0.065
# fold 1 epoch 85 train 0.101 valid 0.095 metric -0.099
# fold 1 epoch 86 train 0.101 valid 0.093 metric -0.071
# fold 1 epoch 87 train 0.103 valid 0.096 metric -0.1
# fold 1 epoch 88 train 0.103 valid 0.093 metric -0.076
# fold 1 epoch 89 train 0.101 valid 0.094 metric -0.084
# fold 1 epoch 90 train 0.101 valid 0.098 metric -0.059
# fold 1 epoch 91 train 0.102 valid 0.093 metric -0.057
# fold 1 epoch 92 train 0.103 valid 0.096 metric -0.103
# fold 1 epoch 93 train 0.101 valid 0.093 metric -0.065
# fold 1 epoch 94 train 0.101 valid 0.094 metric -0.085
# fold 1 epoch 95 train 0.101 valid 0.098 metric -0.063
# fold 1 epoch 96 train 0.102 valid 0.094 metric -0.088
# fold 1 epoch 97 train 0.101 valid 0.096 metric -0.062
# fold 1 epoch 98 train 0.1 valid 0.092 metric -0.078
# fold 1 epoch 99 train 0.1 valid 0.093 metric -0.087
# fold 1 epoch 100 train 0.1 valid 0.094 metric -0.085
# fold 1 epoch 101 train 0.1 valid 0.093 metric -0.089
# fold 1 epoch 102 train 0.101 valid 0.094 metric -0.07
# fold 1 epoch 103 train 0.101 valid 0.096 metric -0.057
# fold 1 epoch 104 train 0.101 valid 0.096 metric -0.081
# fold 1 epoch 105 train 0.101 valid 0.093 metric -0.063
# fold 1 epoch 106 train 0.1 valid 0.093 metric -0.053
# fold 1 epoch 107 train 0.101 valid 0.092 metric -0.057
# fold 1 epoch 108 train 0.1 valid 0.094 metric -0.085
# fold 1 epoch 109 train 0.1 valid 0.092 metric -0.071
# fold 1 epoch 110 train 0.1 valid 0.098 metric -0.082
# fold 1 epoch 111 train 0.1 valid 0.104 metric -0.059
# fold 1 epoch 112 train 0.101 valid 0.093 metric -0.074
# fold 1 epoch 113 train 0.101 valid 0.094 metric -0.076
# fold 1 epoch 114 train 0.101 valid 0.093 metric -0.076
# fold 1 epoch 115 train 0.101 valid 0.094 metric -0.077
# fold 1 epoch 116 train 0.101 valid 0.097 metric -0.071
# fold 1 epoch 117 train 0.1 valid 0.093 metric -0.042
# fold 1 epoch 118 train 0.101 valid 0.093 metric -0.083
# fold 1 epoch 119 train 0.1 valid 0.093 metric -0.029
# fold 1 epoch 120 train 0.101 valid 0.094 metric -0.075
# fold 1 epoch 121 train 0.1 valid 0.092 metric -0.071
# fold 1 epoch 122 train 0.101 valid 0.099 metric -0.099
# fold 1 epoch 123 train 0.101 valid 0.093 metric -0.083
# fold 1 epoch 124 train 0.1 valid 0.094 metric -0.077
# fold 1 epoch 125 train 0.1 valid 0.095 metric -0.083
# fold 1 epoch 126 train 0.101 valid 0.093 metric -0.088
# fold 1 epoch 127 train 0.1 valid 0.094 metric -0.096
# fold 1 epoch 128 train 0.101 valid 0.095 metric -0.082
# fold 1 epoch 129 train 0.1 valid 0.093 metric -0.069
# fold 1 epoch 130 train 0.102 valid 0.092 metric -0.058
# fold 1 epoch 131 train 0.1 valid 0.092 metric -0.071
# fold 1 epoch 132 train 0.101 valid 0.093 metric -0.075
# fold 1 epoch 133 train 0.1 valid 0.092 metric -0.072
# fold 1 epoch 134 train 0.1 valid 0.093 metric -0.055
# fold 1 epoch 135 train 0.101 valid 0.094 metric -0.096
# fold 1 epoch 136 train 0.1 valid 0.092 metric -0.073
# fold 1 epoch 137 train 0.101 valid 0.094 metric -0.075
# fold 1 epoch 138 train 0.1 valid 0.092 metric -0.073
# fold 1 epoch 139 train 0.1 valid 0.094 metric -0.08
# fold 1 epoch 140 train 0.099 valid 0.092 metric -0.079
# fold 1 epoch 141 train 0.101 valid 0.094 metric -0.082
# fold 1 epoch 142 train 0.1 valid 0.092 metric -0.064
# fold 1 epoch 143 train 0.099 valid 0.093 metric -0.085
# fold 1 epoch 144 train 0.1 valid 0.092 metric -0.065
# fold 1 epoch 145 train 0.1 valid 0.093 metric -0.078
# fold 1 epoch 146 train 0.1 valid 0.092 metric -0.081
# fold 1 epoch 147 train 0.1 valid 0.092 metric -0.071
# fold 1 epoch 148 train 0.1 valid 0.093 metric -0.087
# fold 1 epoch 149 train 0.1 valid 0.093 metric -0.083
# fold 1 epoch 150 train 0.099 valid 0.092 metric -0.078
# fold 1 epoch 151 train 0.1 valid 0.092 metric -0.076
# fold 1 epoch 152 train 0.099 valid 0.093 metric -0.081
# fold 1 epoch 153 train 0.099 valid 0.092 metric -0.072
# fold 1 epoch 154 train 0.099 valid 0.096 metric -0.071
# fold 1 epoch 155 train 0.099 valid 0.093 metric -0.078
# fold 1 epoch 156 train 0.099 valid 0.092 metric -0.073
# fold 1 epoch 157 train 0.1 valid 0.092 metric -0.077
# fold 1 epoch 158 train 0.099 valid 0.092 metric -0.084
# fold 1 epoch 159 train 0.1 valid 0.095 metric -0.068
# fold 1 epoch 160 train 0.099 valid 0.093 metric -0.074
# fold 1 epoch 161 train 0.099 valid 0.092 metric -0.076
# fold 1 epoch 162 train 0.099 valid 0.094 metric -0.078
# fold 1 epoch 163 train 0.099 valid 0.093 metric -0.073
# fold 1 epoch 164 train 0.099 valid 0.093 metric -0.074
# fold 1 epoch 165 train 0.099 valid 0.094 metric -0.072
# fold 1 epoch 166 train 0.099 valid 0.094 metric -0.075
# fold 1 epoch 167 train 0.099 valid 0.093 metric -0.082
# fold 1 epoch 168 train 0.099 valid 0.092 metric -0.075
# fold 1 epoch 169 train 0.099 valid 0.093 metric -0.074
# fold 1 epoch 170 train 0.099 valid 0.092 metric -0.076
# fold 1 epoch 171 train 0.099 valid 0.093 metric -0.076
# fold 1 epoch 172 train 0.099 valid 0.092 metric -0.078
# fold 1 epoch 173 train 0.099 valid 0.093 metric -0.076
# fold 1 epoch 174 train 0.099 valid 0.093 metric -0.073
# fold 1 epoch 175 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 176 train 0.099 valid 0.092 metric -0.076
# fold 1 epoch 177 train 0.099 valid 0.093 metric -0.071
# fold 1 epoch 178 train 0.099 valid 0.093 metric -0.077
# fold 1 epoch 179 train 0.099 valid 0.092 metric -0.074
# fold 1 epoch 180 train 0.099 valid 0.093 metric -0.077
# fold 1 epoch 181 train 0.099 valid 0.093 metric -0.076
# fold 1 epoch 182 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 183 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 184 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 185 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 186 train 0.099 valid 0.093 metric -0.074
# fold 1 epoch 187 train 0.099 valid 0.093 metric -0.074
# fold 1 epoch 188 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 189 train 0.099 valid 0.093 metric -0.074
# fold 1 epoch 190 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 191 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 192 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 193 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 194 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 195 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 196 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 197 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 198 train 0.099 valid 0.093 metric -0.075
# fold 1 epoch 199 train 0.099 valid 0.093 metric -0.075
# fold 2 epoch 0 train 0.375 valid 0.119 metric -1.039698334315968e+21
# fold 2 epoch 1 train 0.108 valid 0.1 metric -0.064
# fold 2 epoch 2 train 0.104 valid 0.101 metric -0.074
# fold 2 epoch 3 train 0.105 valid 0.101 metric -0.088
# fold 2 epoch 4 train 0.102 valid 0.1 metric -0.092
# fold 2 epoch 5 train 0.104 valid 0.098 metric -0.048
# fold 2 epoch 6 train 0.102 valid 0.102 metric -0.08
# fold 2 epoch 7 train 0.101 valid 0.105 metric -0.115
# fold 2 epoch 8 train 0.106 valid 0.101 metric -0.092
# fold 2 epoch 9 train 0.073 valid 0.086 metric -1.0399913920765467e+22
# fold 2 epoch 10 train 0.051 valid 0.042 metric -2.6020901475372966e+21
# fold 2 epoch 11 train 0.04 valid 0.037 metric -8.981741895128917e+20
# fold 2 epoch 12 train 0.028 valid 0.025 metric -7.678347290063089e+20
# fold 2 epoch 13 train 0.025 valid 0.024 metric -3.654544038857001e+20
# fold 2 epoch 14 train 0.023 valid 0.026 metric -1.2744771489413823e+20
# fold 2 epoch 15 train 0.024 valid 0.021 metric -3.4598604251184103e+20
# fold 2 epoch 16 train 0.026 valid 0.036 metric -1.1649708010008225e+20
# fold 2 epoch 17 train 0.028 valid 0.02 metric -2.5957915187289185e+20
# fold 2 epoch 18 train 0.021 valid 0.025 metric -6.773050664580223e+19
# fold 2 epoch 19 train 0.022 valid 0.018 metric -2.499901178648944e+20
# fold 2 epoch 20 train 0.025 valid 0.025 metric -5.8131563152542286e+19
# fold 2 epoch 21 train 0.019 valid 0.026 metric -1.7692401624759288e+20
# fold 2 epoch 22 train 0.022 valid 0.019 metric -2.1043459392577264e+20
# fold 2 epoch 23 train 0.02 valid 0.021 metric -2.7071801998424677e+20
# fold 2 epoch 24 train 0.017 valid 0.024 metric -4.887600044985009e+20
# fold 2 epoch 25 train 0.015 valid 0.022 metric -5.553489748608381e+19
# fold 2 epoch 26 train 0.019 valid 0.016 metric -1.2369932381480752e+20
# fold 2 epoch 27 train 0.014 valid 0.015 metric -1.3290576470628236e+20
# fold 2 epoch 28 train 0.014 valid 0.014 metric -1.5409270691788823e+20
# fold 2 epoch 29 train 0.016 valid 0.013 metric -1.1581884809706219e+20
# fold 2 epoch 30 train 0.015 valid 0.013 metric -8.42578727807516e+19
# fold 2 epoch 31 train 0.015 valid 0.015 metric -2.3218943588204744e+20
# fold 2 epoch 32 train 0.014 valid 0.013 metric -2.7488553518306646e+20
# fold 2 epoch 33 train 0.014 valid 0.013 metric -3.423384449296056e+20
# fold 2 epoch 34 train 0.013 valid 0.012 metric -9.51976350257221e+19
# fold 2 epoch 35 train 0.013 valid 0.016 metric -1.6568077248831557e+20
# fold 2 epoch 36 train 0.016 valid 0.014 metric -1.276454217087026e+20
# fold 2 epoch 37 train 0.012 valid 0.013 metric -1.4663034406664592e+20
# fold 2 epoch 38 train 0.013 valid 0.014 metric -6.46518028466146e+19
# fold 2 epoch 39 train 0.013 valid 0.012 metric -8.489468094673152e+19
# fold 2 epoch 40 train 0.013 valid 0.012 metric -1.138940880974656e+20
# fold 2 epoch 41 train 0.013 valid 0.018 metric -3.104272560720982e+20
# fold 2 epoch 42 train 0.013 valid 0.013 metric -6.650215338338343e+19
# fold 2 epoch 43 train 0.013 valid 0.014 metric -1.2904641029733584e+20
# fold 2 epoch 44 train 0.013 valid 0.011 metric -8.187315955781791e+19
# fold 2 epoch 45 train 0.011 valid 0.011 metric -5.4727350674421735e+19
# fold 2 epoch 46 train 0.011 valid 0.01 metric -1.2292302967000338e+20
# fold 2 epoch 47 train 0.012 valid 0.014 metric -2.2906447184971455e+20
# fold 2 epoch 48 train 0.012 valid 0.014 metric -1.5806561173866834e+20
# fold 2 epoch 49 train 0.011 valid 0.01 metric -3.5506522837824086e+19
# fold 2 epoch 50 train 0.011 valid 0.018 metric -2.01584506527013e+20
# fold 2 epoch 51 train 0.012 valid 0.01 metric -1.1612449411259523e+20
# fold 2 epoch 52 train 0.011 valid 0.011 metric -1.0429013518218558e+20
# fold 2 epoch 53 train 0.011 valid 0.021 metric -3.435928407165106e+20
# fold 2 epoch 54 train 0.015 valid 0.011 metric -3.1278783144089264e+19
# fold 2 epoch 55 train 0.011 valid 0.013 metric -1.2598934372627936e+20
# fold 2 epoch 56 train 0.012 valid 0.012 metric -5.4217562241922785e+19
# fold 2 epoch 57 train 0.012 valid 0.012 metric -1.57636598031698e+20
# fold 2 epoch 58 train 0.011 valid 0.011 metric -9.033632057637881e+19
# fold 2 epoch 59 train 0.011 valid 0.011 metric -8.546316390500093e+19
# fold 2 epoch 60 train 0.01 valid 0.01 metric -2.457959485679794e+19
# fold 2 epoch 61 train 0.01 valid 0.009 metric -7.065959390738673e+19
# fold 2 epoch 62 train 0.01 valid 0.012 metric -6.39689728143719e+19
# fold 2 epoch 63 train 0.011 valid 0.011 metric -3.4783882176158708e+19
# fold 2 epoch 64 train 0.011 valid 0.01 metric -2.240536405822053e+19
# fold 2 epoch 65 train 0.01 valid 0.01 metric -1.331434503344167e+20
# fold 2 epoch 66 train 0.01 valid 0.01 metric -4.075053398292126e+19
# fold 2 epoch 67 train 0.009 valid 0.01 metric -4.761088531853165e+19
# fold 2 epoch 68 train 0.01 valid 0.008 metric -3.8501148624867705e+19
# fold 2 epoch 69 train 0.009 valid 0.009 metric -6.452801220807519e+19
# fold 2 epoch 70 train 0.009 valid 0.01 metric -3.5681236622552433e+19
# fold 2 epoch 71 train 0.01 valid 0.009 metric -1.0138092064284051e+20
# fold 2 epoch 72 train 0.009 valid 0.01 metric -7.627098004779326e+19
# fold 2 epoch 73 train 0.009 valid 0.009 metric -4.920246094632664e+19
# fold 2 epoch 74 train 0.01 valid 0.01 metric -1.9297677456491508e+19
# fold 2 epoch 75 train 0.008 valid 0.008 metric -4.87129688914029e+19
# fold 2 epoch 76 train 0.008 valid 0.008 metric -7.825520419670893e+19
# fold 2 epoch 77 train 0.008 valid 0.009 metric -1.0665141608557044e+20
# fold 2 epoch 78 train 0.008 valid 0.01 metric -5.403285236521369e+19
# fold 2 epoch 79 train 0.009 valid 0.009 metric -3.1453441656113672e+19
# fold 2 epoch 80 train 0.008 valid 0.008 metric -2.992037570907404e+19
# fold 2 epoch 81 train 0.009 valid 0.009 metric -4.156746307139047e+19
# fold 2 epoch 82 train 0.008 valid 0.009 metric -1.0261858736843235e+20
# fold 2 epoch 83 train 0.009 valid 0.012 metric -1.1289990874754335e+20
# fold 2 epoch 84 train 0.008 valid 0.008 metric -1.4221187452051524e+19
# fold 2 epoch 85 train 0.008 valid 0.012 metric -7.188062187864775e+19
# fold 2 epoch 86 train 0.008 valid 0.008 metric -3.2759175475184464e+19
# fold 2 epoch 87 train 0.008 valid 0.008 metric -3.7526269095331e+19
# fold 2 epoch 88 train 0.007 valid 0.008 metric -2.54810625212301e+19
# fold 2 epoch 89 train 0.009 valid 0.01 metric -8.062848878229216e+19
# fold 2 epoch 90 train 0.008 valid 0.008 metric -1.7549980837525195e+19
# fold 2 epoch 91 train 0.008 valid 0.008 metric -1.7900921645061591e+19
# fold 2 epoch 92 train 0.008 valid 0.008 metric -1.642441814976418e+19
# fold 2 epoch 93 train 0.007 valid 0.008 metric -2.468592847061454e+19
# fold 2 epoch 94 train 0.007 valid 0.008 metric -2.5589838645243716e+19
# fold 2 epoch 95 train 0.007 valid 0.008 metric -4.528465024778627e+19
# fold 2 epoch 96 train 0.008 valid 0.007 metric -3.481206076570904e+19
# fold 2 epoch 97 train 0.007 valid 0.007 metric -1.1489598877663093e+19
# fold 2 epoch 98 train 0.007 valid 0.009 metric -3.6316210467780313e+19
# fold 2 epoch 99 train 0.007 valid 0.007 metric -6.565311990644934e+18
# fold 2 epoch 100 train 0.007 valid 0.007 metric -8.663171973589708e+19
# fold 2 epoch 101 train 0.007 valid 0.007 metric -5.9617032613816476e+19
# fold 2 epoch 102 train 0.007 valid 0.008 metric -5.0926881013837816e+19
# fold 2 epoch 103 train 0.007 valid 0.007 metric -5.6419558850277196e+19
# fold 2 epoch 104 train 0.008 valid 0.008 metric -4.5765632537742385e+19
# fold 2 epoch 105 train 0.007 valid 0.006 metric -3.1666277426838094e+19
# fold 2 epoch 106 train 0.007 valid 0.009 metric -9.731670069047433e+18
# fold 2 epoch 107 train 0.006 valid 0.007 metric -2.6772103557368963e+19
# fold 2 epoch 108 train 0.007 valid 0.007 metric -5.490931833183079e+19
# fold 2 epoch 109 train 0.007 valid 0.008 metric -2.091131959604742e+19
# fold 2 epoch 110 train 0.007 valid 0.008 metric -2.923744341149161e+18
# fold 2 epoch 111 train 0.007 valid 0.006 metric -2.3267715355835085e+19
# fold 2 epoch 112 train 0.006 valid 0.006 metric -4.531528344243675e+19
# fold 2 epoch 113 train 0.006 valid 0.007 metric -1.012360245020703e+19
# fold 2 epoch 114 train 0.006 valid 0.006 metric -1.9880631261419907e+18
# fold 2 epoch 115 train 0.006 valid 0.006 metric -3.934326183496213e+19
# fold 2 epoch 116 train 0.005 valid 0.007 metric -3.766399533709483e+19
# fold 2 epoch 117 train 0.006 valid 0.006 metric -1.6301933545552366e+19
# fold 2 epoch 118 train 0.006 valid 0.006 metric -2.140357082488512e+19
# fold 2 epoch 119 train 0.005 valid 0.006 metric -8.292995760936751e+17
# fold 2 epoch 120 train 0.006 valid 0.007 metric -4.715955943801704e+19
# fold 2 epoch 121 train 0.005 valid 0.007 metric -1.680144805097027e+19
# fold 2 epoch 122 train 0.006 valid 0.007 metric -1.444878306255884e+19
# fold 2 epoch 123 train 0.006 valid 0.006 metric -3.755965199723971e+19
# fold 2 epoch 124 train 0.005 valid 0.006 metric -1.3211000569147424e+17
# fold 2 epoch 125 train 0.005 valid 0.006 metric -2.779711169144702e+18
# fold 2 epoch 126 train 0.005 valid 0.006 metric -3.1651665829235593e+19
# fold 2 epoch 127 train 0.005 valid 0.006 metric -9.277036804235246e+18
# fold 2 epoch 128 train 0.005 valid 0.006 metric -3.857713268115131e+18
# fold 2 epoch 129 train 0.005 valid 0.006 metric -2.441719802344508e+19
# fold 2 epoch 130 train 0.005 valid 0.008 metric 0.402
# fold 2 epoch 131 train 0.006 valid 0.006 metric -2.7339569412926083e+19
# fold 2 epoch 132 train 0.006 valid 0.007 metric -2.2334191617014938e+18
# fold 2 epoch 133 train 0.005 valid 0.005 metric -2.8155000658684575e+18
# fold 2 epoch 134 train 0.005 valid 0.007 metric -1.3648737079514378e+18
# fold 2 epoch 135 train 0.005 valid 0.005 metric -2.671239039818078e+17
# fold 2 epoch 136 train 0.005 valid 0.006 metric -8.077431717384568e+18
# fold 2 epoch 137 train 0.005 valid 0.006 metric -4.679444821798964e+18
# fold 2 epoch 138 train 0.005 valid 0.006 metric -9.283594567577657e+18
# fold 2 epoch 139 train 0.005 valid 0.005 metric -4.270464454061784e+18
# fold 2 epoch 140 train 0.005 valid 0.006 metric -3.440612564874891e+16
# fold 2 epoch 141 train 0.005 valid 0.006 metric -1.048044379084298e+19
# fold 2 epoch 142 train 0.005 valid 0.006 metric -5.358513479128564e+19
# fold 2 epoch 143 train 0.005 valid 0.006 metric -7.672271295439541e+18
# fold 2 epoch 144 train 0.005 valid 0.005 metric -1.6202873293854945e+18
# fold 2 epoch 145 train 0.005 valid 0.005 metric -3.844083626055884e+17
# fold 2 epoch 146 train 0.004 valid 0.005 metric -8.322203280045885e+18
# fold 2 epoch 147 train 0.004 valid 0.005 metric -6.244273568193687e+16
# fold 2 epoch 148 train 0.004 valid 0.006 metric -4.2011075661650515e+17
# fold 2 epoch 149 train 0.005 valid 0.006 metric -5.097280947692205e+18
# fold 2 epoch 150 train 0.004 valid 0.005 metric -4.3256287234988544e+17
# fold 2 epoch 151 train 0.004 valid 0.005 metric -8.272093971757274e+16
# fold 2 epoch 152 train 0.004 valid 0.005 metric -2.172465170161691e+18
# fold 2 epoch 153 train 0.005 valid 0.005 metric -5.678186016599605e+17
# fold 2 epoch 154 train 0.005 valid 0.005 metric 0.372
# fold 2 epoch 155 train 0.004 valid 0.005 metric -5.61523595158529e+16
# fold 2 epoch 156 train 0.004 valid 0.005 metric -5.088771260632449e+16
# fold 2 epoch 157 train 0.004 valid 0.005 metric 0.475
# fold 2 epoch 158 train 0.004 valid 0.005 metric 0.487
# fold 2 epoch 159 train 0.004 valid 0.005 metric -1.5438113354310812e+18
# fold 2 epoch 160 train 0.004 valid 0.005 metric 0.477
# fold 2 epoch 161 train 0.004 valid 0.005 metric -4.8461334901580616e+16
# fold 2 epoch 162 train 0.004 valid 0.005 metric 0.495
# fold 2 epoch 163 train 0.004 valid 0.005 metric 0.495
# fold 2 epoch 164 train 0.004 valid 0.005 metric 0.466
# fold 2 epoch 165 train 0.004 valid 0.005 metric 0.477
# fold 2 epoch 166 train 0.004 valid 0.005 metric 0.458
# fold 2 epoch 167 train 0.004 valid 0.005 metric 0.468
# fold 2 epoch 168 train 0.004 valid 0.005 metric -1.8389716008491988e+16
# fold 2 epoch 169 train 0.004 valid 0.005 metric 0.499
# fold 2 epoch 170 train 0.004 valid 0.005 metric 0.495
# fold 2 epoch 171 train 0.004 valid 0.005 metric 0.498
# fold 2 epoch 172 train 0.004 valid 0.005 metric 0.493
# fold 2 epoch 173 train 0.004 valid 0.005 metric 0.496
# fold 2 epoch 174 train 0.004 valid 0.005 metric 0.491
# fold 2 epoch 175 train 0.004 valid 0.005 metric 0.505
# fold 2 epoch 176 train 0.004 valid 0.005 metric 0.506
# fold 2 epoch 177 train 0.004 valid 0.005 metric 0.501
# fold 2 epoch 178 train 0.004 valid 0.005 metric 0.507
# fold 2 epoch 179 train 0.004 valid 0.005 metric 0.51
# fold 2 epoch 180 train 0.004 valid 0.005 metric 0.51
# fold 2 epoch 181 train 0.004 valid 0.005 metric 0.498
# fold 2 epoch 182 train 0.004 valid 0.005 metric 0.515
# fold 2 epoch 183 train 0.004 valid 0.005 metric 0.511
# fold 2 epoch 184 train 0.004 valid 0.005 metric 0.51
# fold 2 epoch 185 train 0.004 valid 0.005 metric 0.509
# fold 2 epoch 186 train 0.004 valid 0.005 metric 0.509
# fold 2 epoch 187 train 0.004 valid 0.005 metric 0.509
# fold 2 epoch 188 train 0.004 valid 0.005 metric 0.505
# fold 2 epoch 189 train 0.004 valid 0.005 metric 0.513
# fold 2 epoch 190 train 0.004 valid 0.005 metric 0.512
# fold 2 epoch 191 train 0.004 valid 0.005 metric 0.514
# fold 2 epoch 192 train 0.004 valid 0.005 metric 0.513
# fold 2 epoch 193 train 0.004 valid 0.005 metric 0.513
# fold 2 epoch 194 train 0.004 valid 0.005 metric 0.514
# fold 2 epoch 195 train 0.004 valid 0.005 metric 0.512
# fold 2 epoch 196 train 0.004 valid 0.005 metric 0.514
# fold 2 epoch 197 train 0.004 valid 0.005 metric 0.514
# fold 2 epoch 198 train 0.004 valid 0.005 metric 0.514
# fold 2 epoch 199 train 0.004 valid 0.005 metric 0.514
# fold 3 epoch 0 train 0.368 valid 0.12 metric -0.118
# fold 3 epoch 1 train 0.108 valid 0.101 metric -0.057
# fold 3 epoch 2 train 0.102 valid 0.1 metric -0.102
# fold 3 epoch 3 train 0.103 valid 0.108 metric -0.085
# fold 3 epoch 4 train 0.105 valid 0.104 metric -0.056
# fold 3 epoch 5 train 0.101 valid 0.108 metric -0.061
# fold 3 epoch 6 train 0.103 valid 0.102 metric -0.06
# fold 3 epoch 7 train 0.103 valid 0.104 metric -0.089
# fold 3 epoch 8 train 0.107 valid 0.104 metric -0.048
# fold 3 epoch 9 train 0.104 valid 0.101 metric -0.048
# fold 3 epoch 10 train 0.102 valid 0.103 metric -0.065
# fold 3 epoch 11 train 0.102 valid 0.107 metric -1.6919413875435647e+22
# fold 3 epoch 12 train 0.085 valid 0.077 metric -1.5597668594290612e+22
# fold 3 epoch 13 train 0.051 valid 0.05 metric -1.0340517589986911e+21
# fold 3 epoch 14 train 0.034 valid 0.034 metric -9.40342218013181e+20
# fold 3 epoch 15 train 0.029 valid 0.023 metric -3.5824350852080284e+20
# fold 3 epoch 16 train 0.026 valid 0.046 metric -7.556502745152975e+20
# fold 3 epoch 17 train 0.028 valid 0.02 metric -2.198100654076573e+20
# fold 3 epoch 18 train 0.021 valid 0.022 metric -6.103567671007637e+19
# fold 3 epoch 19 train 0.027 valid 0.027 metric -6.82599703083954e+20
# fold 3 epoch 20 train 0.024 valid 0.022 metric -2.2784127917623843e+20
# fold 3 epoch 21 train 0.025 valid 0.019 metric -8.338524737056542e+19
# fold 3 epoch 22 train 0.019 valid 0.025 metric -9.642482134855675e+19
# fold 3 epoch 23 train 0.022 valid 0.02 metric -8.802967957688988e+19
# fold 3 epoch 24 train 0.019 valid 0.019 metric -6.129513494330697e+19
# fold 3 epoch 25 train 0.02 valid 0.022 metric -8.266779996032559e+19
# fold 3 epoch 26 train 0.018 valid 0.017 metric -2.5740132732414657e+20
# fold 3 epoch 27 train 0.021 valid 0.023 metric -6.128484868587226e+19
# fold 3 epoch 28 train 0.02 valid 0.018 metric -2.7467127999998457e+20
# fold 3 epoch 29 train 0.018 valid 0.017 metric -6.550607502638574e+19
# fold 3 epoch 30 train 0.02 valid 0.023 metric -1.0323984012289386e+20
# fold 3 epoch 31 train 0.018 valid 0.019 metric -6.975479295261497e+19
# fold 3 epoch 32 train 0.019 valid 0.026 metric -1.9486854486426786e+20
# fold 3 epoch 33 train 0.02 valid 0.029 metric -3.31471176303356e+20
# fold 3 epoch 34 train 0.019 valid 0.019 metric -2.029259530615657e+20
# fold 3 epoch 35 train 0.015 valid 0.017 metric -1.427123712861981e+20
# fold 3 epoch 36 train 0.019 valid 0.019 metric -3.1539114430365316e+20
# fold 3 epoch 37 train 0.016 valid 0.013 metric -2.747231431887981e+20
# fold 3 epoch 38 train 0.012 valid 0.014 metric -6.5736319043382034e+19
# fold 3 epoch 39 train 0.013 valid 0.013 metric -1.3849163744779957e+20
# fold 3 epoch 40 train 0.013 valid 0.016 metric -4.884171703699318e+19
# fold 3 epoch 41 train 0.013 valid 0.013 metric -9.445928489709158e+19
# fold 3 epoch 42 train 0.012 valid 0.012 metric -4.064402449231543e+19
# fold 3 epoch 43 train 0.013 valid 0.014 metric -8.897220405193463e+19
# fold 3 epoch 44 train 0.013 valid 0.014 metric -8.621668113837526e+19
# fold 3 epoch 45 train 0.013 valid 0.014 metric -2.1630171657861215e+20
# fold 3 epoch 46 train 0.012 valid 0.013 metric -1.4031099800562765e+20
# fold 3 epoch 47 train 0.012 valid 0.011 metric -9.717039327104534e+19
# fold 3 epoch 48 train 0.012 valid 0.012 metric -1.016478488710242e+20
# fold 3 epoch 49 train 0.015 valid 0.015 metric -1.087915302522947e+20
# fold 3 epoch 50 train 0.012 valid 0.011 metric -5.221710121993206e+19
# fold 3 epoch 51 train 0.011 valid 0.012 metric -8.647245913443151e+19
# fold 3 epoch 52 train 0.011 valid 0.013 metric -1.3346396389463918e+20
# fold 3 epoch 53 train 0.012 valid 0.012 metric -7.720233482758919e+19
# fold 3 epoch 54 train 0.01 valid 0.012 metric -8.015529016986124e+19
# fold 3 epoch 55 train 0.011 valid 0.012 metric -8.765188568035805e+19
# fold 3 epoch 56 train 0.01 valid 0.011 metric -7.638510581740637e+19
# fold 3 epoch 57 train 0.01 valid 0.012 metric -7.255121482510356e+19
# fold 3 epoch 58 train 0.013 valid 0.014 metric -7.075519017208795e+19
# fold 3 epoch 59 train 0.011 valid 0.013 metric -2.1604888142840178e+20
# fold 3 epoch 60 train 0.011 valid 0.012 metric -1.262544380062464e+20
# fold 3 epoch 61 train 0.01 valid 0.011 metric -1.0620262582048104e+20
# fold 3 epoch 62 train 0.011 valid 0.012 metric -1.614909047090424e+20
# fold 3 epoch 63 train 0.009 valid 0.009 metric -5.535209726552207e+19
# fold 3 epoch 64 train 0.01 valid 0.01 metric -5.605166939221201e+19
# fold 3 epoch 65 train 0.01 valid 0.01 metric -1.6022337553845993e+20
# fold 3 epoch 66 train 0.009 valid 0.009 metric -1.4749925569413788e+19
# fold 3 epoch 67 train 0.009 valid 0.012 metric -8.716930726825083e+19
# fold 3 epoch 68 train 0.01 valid 0.01 metric -6.634641568756464e+19
# fold 3 epoch 69 train 0.009 valid 0.01 metric -6.752457482846769e+19
# fold 3 epoch 70 train 0.01 valid 0.009 metric -9.456705532853373e+19
# fold 3 epoch 71 train 0.009 valid 0.01 metric -8.5862929494888e+19
# fold 3 epoch 72 train 0.009 valid 0.01 metric -2.1121366606238474e+19
# fold 3 epoch 73 train 0.01 valid 0.012 metric -6.851009295273135e+19
# fold 3 epoch 74 train 0.009 valid 0.01 metric -3.774045896194579e+19
# fold 3 epoch 75 train 0.009 valid 0.011 metric -5.532931980378142e+19
# fold 3 epoch 76 train 0.01 valid 0.01 metric -6.635486387437057e+19
# fold 3 epoch 77 train 0.009 valid 0.01 metric -6.767858912545616e+19
# fold 3 epoch 78 train 0.008 valid 0.008 metric -1.7385880354621002e+19
# fold 3 epoch 79 train 0.008 valid 0.008 metric -6.462691713508735e+19
# fold 3 epoch 80 train 0.009 valid 0.009 metric -8.734210538613808e+19
# fold 3 epoch 81 train 0.008 valid 0.008 metric -5.4618465625293545e+19
# fold 3 epoch 82 train 0.008 valid 0.008 metric -5.803937434147253e+19
# fold 3 epoch 83 train 0.008 valid 0.008 metric -7.215959157873915e+19
# fold 3 epoch 84 train 0.008 valid 0.008 metric -2.718171265415476e+19
# fold 3 epoch 85 train 0.008 valid 0.009 metric -1.1793355835766825e+20
# fold 3 epoch 86 train 0.008 valid 0.01 metric -4.931883651885906e+19
# fold 3 epoch 87 train 0.009 valid 0.008 metric -4.422698829433094e+19
# fold 3 epoch 88 train 0.007 valid 0.009 metric -1.972431855649558e+19
# fold 3 epoch 89 train 0.008 valid 0.009 metric -7.789661008044897e+18
# fold 3 epoch 90 train 0.007 valid 0.009 metric -3.773863199755713e+19
# fold 3 epoch 91 train 0.008 valid 0.01 metric -8.316589056266124e+19
# fold 3 epoch 92 train 0.007 valid 0.009 metric -3.287032124050705e+19
# fold 3 epoch 93 train 0.008 valid 0.008 metric -3.5815009675229233e+19
# fold 3 epoch 94 train 0.007 valid 0.008 metric -1.3530400069531613e+19
# fold 3 epoch 95 train 0.007 valid 0.01 metric -3.4608713126807986e+19
# fold 3 epoch 96 train 0.007 valid 0.01 metric -5.6813457739993326e+19
# fold 3 epoch 97 train 0.007 valid 0.007 metric -1.5653108002348868e+19
# fold 3 epoch 98 train 0.007 valid 0.007 metric -2.1271299329899307e+19
# fold 3 epoch 99 train 0.007 valid 0.01 metric -3.5780147109589443e+19
# fold 3 epoch 100 train 0.008 valid 0.01 metric -2.303244852449909e+19
# fold 3 epoch 101 train 0.008 valid 0.008 metric -2.1095359485629133e+19
# fold 3 epoch 102 train 0.007 valid 0.008 metric -3.6109605641881616e+19
# fold 3 epoch 103 train 0.006 valid 0.007 metric -5.592806269798849e+19
# fold 3 epoch 104 train 0.007 valid 0.008 metric -2.1222306393725067e+19
# fold 3 epoch 105 train 0.008 valid 0.008 metric -3.116411084516655e+19
# fold 3 epoch 106 train 0.007 valid 0.008 metric -2.1132708814777704e+19
# fold 3 epoch 107 train 0.006 valid 0.007 metric -7.577016028117015e+18
# fold 3 epoch 108 train 0.006 valid 0.008 metric -4.439811726363683e+19
# fold 3 epoch 109 train 0.007 valid 0.008 metric -1.5892928694295663e+19
# fold 3 epoch 110 train 0.006 valid 0.007 metric -3.994252537570538e+19
# fold 3 epoch 111 train 0.006 valid 0.007 metric -1.927769423844464e+19
# fold 3 epoch 112 train 0.006 valid 0.007 metric -3.5219792310124507e+19
# fold 3 epoch 113 train 0.006 valid 0.008 metric -9.589247545653375e+18
# fold 3 epoch 114 train 0.006 valid 0.009 metric -4.6154987318387606e+19
# fold 3 epoch 115 train 0.007 valid 0.007 metric -1.6967089494071794e+19
# fold 3 epoch 116 train 0.006 valid 0.008 metric -5.908829044758567e+18
# fold 3 epoch 117 train 0.006 valid 0.007 metric -8.76514386809883e+18
# fold 3 epoch 118 train 0.005 valid 0.007 metric -8.698036876736952e+18
# fold 3 epoch 119 train 0.006 valid 0.007 metric -1.7821068329825868e+19
# fold 3 epoch 120 train 0.006 valid 0.007 metric -1.9256687045155803e+19
# fold 3 epoch 121 train 0.005 valid 0.007 metric -2.114607230494961e+19
# fold 3 epoch 122 train 0.005 valid 0.008 metric -4.027038220829383e+19
# fold 3 epoch 123 train 0.006 valid 0.008 metric -3.742603004380548e+19
# fold 3 epoch 124 train 0.006 valid 0.006 metric -1.926843811202397e+19
# fold 3 epoch 125 train 0.005 valid 0.006 metric -2.0753637113740575e+19
# fold 3 epoch 126 train 0.005 valid 0.007 metric -6.402605652526685e+18
# fold 3 epoch 127 train 0.005 valid 0.006 metric -5.7932501861381e+18
# fold 3 epoch 128 train 0.005 valid 0.006 metric -1.4562878629297398e+19
# fold 3 epoch 129 train 0.005 valid 0.007 metric -1.2060841630713145e+19
# fold 3 epoch 130 train 0.006 valid 0.008 metric -2.5780770035955053e+19
# fold 3 epoch 131 train 0.006 valid 0.006 metric -1.1382747319262345e+19
# fold 3 epoch 132 train 0.005 valid 0.006 metric -1.9714160526347996e+18
# fold 3 epoch 133 train 0.005 valid 0.006 metric -4.765360173493479e+18
# fold 3 epoch 134 train 0.005 valid 0.006 metric -1.1663732529235399e+19
# fold 3 epoch 135 train 0.005 valid 0.007 metric -6.243897299964918e+17
# fold 3 epoch 136 train 0.005 valid 0.006 metric -1.3109528127392154e+19
# fold 3 epoch 137 train 0.005 valid 0.006 metric -9.530161288248986e+18
# fold 3 epoch 138 train 0.005 valid 0.007 metric -7.599906662581759e+18
# fold 3 epoch 139 train 0.005 valid 0.006 metric -5.415797499079894e+18
# fold 3 epoch 140 train 0.005 valid 0.006 metric -1.6531297000790202e+19
# fold 3 epoch 141 train 0.004 valid 0.006 metric -2.6685162799772303e+18
# fold 3 epoch 142 train 0.005 valid 0.006 metric -1.4192300619455017e+18
# fold 3 epoch 143 train 0.004 valid 0.006 metric -6.543494566675994e+17
# fold 3 epoch 144 train 0.005 valid 0.007 metric -6.915456084735028e+18
# fold 3 epoch 145 train 0.005 valid 0.006 metric -2.3320389166104525e+18
# fold 3 epoch 146 train 0.005 valid 0.006 metric -5.755940836877703e+18
# fold 3 epoch 147 train 0.005 valid 0.006 metric -1.3490777155741011e+17
# fold 3 epoch 148 train 0.004 valid 0.006 metric -1.9270950093522545e+18
# fold 3 epoch 149 train 0.004 valid 0.006 metric -4.6310366850756416e+17
# fold 3 epoch 150 train 0.004 valid 0.006 metric -9.105239885755547e+17
# fold 3 epoch 151 train 0.004 valid 0.006 metric -1.3495474970795238e+17
# fold 3 epoch 152 train 0.004 valid 0.006 metric 0.478
# fold 3 epoch 153 train 0.004 valid 0.006 metric -7.562284768260232e+17
# fold 3 epoch 154 train 0.004 valid 0.006 metric 0.478
# fold 3 epoch 155 train 0.004 valid 0.006 metric -4.515848590155264e+16
# fold 3 epoch 156 train 0.004 valid 0.006 metric 0.456
# fold 3 epoch 157 train 0.004 valid 0.006 metric -5.634340761238752e+16
# fold 3 epoch 158 train 0.004 valid 0.006 metric 0.457
# fold 3 epoch 159 train 0.004 valid 0.006 metric -2.507466786754773e+18
# fold 3 epoch 160 train 0.004 valid 0.006 metric 0.483
# fold 3 epoch 161 train 0.004 valid 0.006 metric 0.433
# fold 3 epoch 162 train 0.004 valid 0.006 metric -1.7709896776994674e+16
# fold 3 epoch 163 train 0.004 valid 0.006 metric 0.401
# fold 3 epoch 164 train 0.004 valid 0.006 metric -7.119781158204413e+17
# fold 3 epoch 165 train 0.004 valid 0.006 metric 0.49
# fold 3 epoch 166 train 0.004 valid 0.006 metric 0.482
# fold 3 epoch 167 train 0.004 valid 0.006 metric 0.494
# fold 3 epoch 168 train 0.004 valid 0.005 metric 0.493
# fold 3 epoch 169 train 0.004 valid 0.006 metric -7.016788672493544e+17
# fold 3 epoch 170 train 0.004 valid 0.006 metric 0.445
# fold 3 epoch 171 train 0.004 valid 0.006 metric 0.499
# fold 3 epoch 172 train 0.004 valid 0.006 metric -9.417670242611832e+16
# fold 3 epoch 173 train 0.004 valid 0.006 metric 0.507
# fold 3 epoch 174 train 0.004 valid 0.006 metric 0.505
# fold 3 epoch 175 train 0.004 valid 0.006 metric 0.493
# fold 3 epoch 176 train 0.004 valid 0.006 metric 0.508
# fold 3 epoch 177 train 0.004 valid 0.006 metric 0.499
# fold 3 epoch 178 train 0.004 valid 0.006 metric 0.507
# fold 3 epoch 179 train 0.004 valid 0.005 metric 0.508
# fold 3 epoch 180 train 0.004 valid 0.005 metric 0.507
# fold 3 epoch 181 train 0.004 valid 0.006 metric 0.509
# fold 3 epoch 182 train 0.004 valid 0.006 metric 0.496
# fold 3 epoch 183 train 0.004 valid 0.006 metric 0.501
# fold 3 epoch 184 train 0.004 valid 0.006 metric 0.509
# fold 3 epoch 185 train 0.004 valid 0.006 metric 0.502
# fold 3 epoch 186 train 0.004 valid 0.006 metric 0.49
# fold 3 epoch 187 train 0.004 valid 0.006 metric 0.502
# fold 3 epoch 188 train 0.004 valid 0.006 metric 0.501
# fold 3 epoch 189 train 0.004 valid 0.006 metric 0.501
# fold 3 epoch 190 train 0.004 valid 0.005 metric 0.512
# fold 3 epoch 191 train 0.004 valid 0.006 metric 0.507
# fold 3 epoch 192 train 0.004 valid 0.006 metric 0.508
# fold 3 epoch 193 train 0.004 valid 0.006 metric 0.508
# fold 3 epoch 194 train 0.004 valid 0.006 metric 0.504
# fold 3 epoch 195 train 0.003 valid 0.006 metric 0.505
# fold 3 epoch 196 train 0.004 valid 0.006 metric 0.507
# fold 3 epoch 197 train 0.004 valid 0.006 metric 0.506
# fold 3 epoch 198 train 0.004 valid 0.006 metric 0.507
# fold 3 epoch 199 train 0.003 valid 0.006 metric 0.507
# fold 4 epoch 0 train 0.382 valid 0.137 metric -4.08918874425293e+21
# fold 4 epoch 1 train 0.105 valid 0.113 metric -0.084
# fold 4 epoch 2 train 0.104 valid 0.114 metric -0.084
# fold 4 epoch 3 train 0.104 valid 0.127 metric -0.069
# fold 4 epoch 4 train 0.105 valid 0.122 metric -0.022
# fold 4 epoch 5 train 0.101 valid 0.113 metric -0.084
# fold 4 epoch 6 train 0.102 valid 0.125 metric -0.02
# fold 4 epoch 7 train 0.102 valid 0.117 metric -0.103
# fold 4 epoch 8 train 0.099 valid 0.112 metric -0.096
# fold 4 epoch 9 train 0.103 valid 0.119 metric -0.052
# fold 4 epoch 10 train 0.099 valid 0.121 metric -0.048
# fold 4 epoch 11 train 0.1 valid 0.111 metric -0.07
# fold 4 epoch 12 train 0.098 valid 0.119 metric -0.053
# fold 4 epoch 13 train 0.101 valid 0.115 metric -0.057
# fold 4 epoch 14 train 0.097 valid 0.129 metric -0.029
# fold 4 epoch 15 train 0.101 valid 0.113 metric -0.083
# fold 4 epoch 16 train 0.102 valid 0.112 metric -0.061
# fold 4 epoch 17 train 0.098 valid 0.112 metric -0.062
# fold 4 epoch 18 train 0.09 valid 0.07 metric -6.807975945090853e+21
# fold 4 epoch 19 train 0.042 valid 0.056 metric -3.56380477298221e+21
# fold 4 epoch 20 train 0.032 valid 0.053 metric -1.5299038711899687e+21
# fold 4 epoch 21 train 0.031 valid 0.028 metric -5.924130380031741e+20
# fold 4 epoch 22 train 0.026 valid 0.03 metric -2.4487966374425503e+20
# fold 4 epoch 23 train 0.029 valid 0.024 metric -2.7385635414483386e+20
# fold 4 epoch 24 train 0.024 valid 0.022 metric -2.9552386430920996e+20
# fold 4 epoch 25 train 0.021 valid 0.026 metric -4.125932835828336e+20
# fold 4 epoch 26 train 0.021 valid 0.018 metric -1.3563916025674508e+20
# fold 4 epoch 27 train 0.022 valid 0.022 metric -3.765417516279179e+19
# fold 4 epoch 28 train 0.022 valid 0.024 metric -1.1423367632379003e+20
# fold 4 epoch 29 train 0.026 valid 0.026 metric -4.123729897983025e+20
# fold 4 epoch 30 train 0.02 valid 0.02 metric -2.217975548279749e+19
# fold 4 epoch 31 train 0.022 valid 0.022 metric -1.0473014672079202e+20
# fold 4 epoch 32 train 0.021 valid 0.018 metric -1.3905519128815732e+20
# fold 4 epoch 33 train 0.019 valid 0.017 metric -1.512415475618833e+20
# fold 4 epoch 34 train 0.017 valid 0.014 metric -2.4810576364112088e+20
# fold 4 epoch 35 train 0.02 valid 0.027 metric -1.5647918145498307e+20
# fold 4 epoch 36 train 0.018 valid 0.012 metric -1.3641908014230274e+20
# fold 4 epoch 37 train 0.014 valid 0.015 metric -2.5425259061622535e+20
# fold 4 epoch 38 train 0.014 valid 0.013 metric -7.915324156145544e+19
# fold 4 epoch 39 train 0.013 valid 0.011 metric -7.452669291799308e+19
# fold 4 epoch 40 train 0.014 valid 0.013 metric -1.859031878839963e+20
# fold 4 epoch 41 train 0.012 valid 0.012 metric -1.2932055813732152e+20
# fold 4 epoch 42 train 0.012 valid 0.013 metric -1.2415487105418492e+20
# fold 4 epoch 43 train 0.012 valid 0.013 metric -1.3593625644194269e+20
# fold 4 epoch 44 train 0.012 valid 0.013 metric -1.844892460491549e+20
# fold 4 epoch 45 train 0.015 valid 0.012 metric -1.164240747158855e+20
# fold 4 epoch 46 train 0.013 valid 0.014 metric -6.353644021750435e+19
# fold 4 epoch 47 train 0.012 valid 0.012 metric -5.640096391877117e+19
# fold 4 epoch 48 train 0.014 valid 0.012 metric -2.0972286252045268e+20
# fold 4 epoch 49 train 0.013 valid 0.013 metric -1.5829264061698235e+20
# fold 4 epoch 50 train 0.013 valid 0.01 metric -9.061228938409452e+19
# fold 4 epoch 51 train 0.011 valid 0.013 metric -1.6357638671775128e+20
# fold 4 epoch 52 train 0.011 valid 0.012 metric -9.310593536631372e+19
# fold 4 epoch 53 train 0.01 valid 0.011 metric -9.608226915236623e+19
# fold 4 epoch 54 train 0.01 valid 0.01 metric -6.722574587860878e+19
# fold 4 epoch 55 train 0.012 valid 0.011 metric -1.3414509809086623e+20
# fold 4 epoch 56 train 0.01 valid 0.01 metric -1.270514582739927e+20
# fold 4 epoch 57 train 0.012 valid 0.011 metric -5.918229402012225e+19
# fold 4 epoch 58 train 0.01 valid 0.01 metric -6.726157884610898e+19
# fold 4 epoch 59 train 0.012 valid 0.016 metric -1.0854860167344854e+20
# fold 4 epoch 60 train 0.011 valid 0.012 metric -1.668872502636742e+20
# fold 4 epoch 61 train 0.009 valid 0.009 metric -5.26513270660938e+19
# fold 4 epoch 62 train 0.009 valid 0.01 metric -8.333012808994885e+19
# fold 4 epoch 63 train 0.01 valid 0.011 metric -7.54125932465767e+19
# fold 4 epoch 64 train 0.009 valid 0.009 metric -1.1371267703606732e+20
# fold 4 epoch 65 train 0.009 valid 0.009 metric -7.139708999499043e+18
# fold 4 epoch 66 train 0.01 valid 0.011 metric -1.4523689254362624e+19
# fold 4 epoch 67 train 0.011 valid 0.009 metric -6.039008473765399e+19
# fold 4 epoch 68 train 0.009 valid 0.009 metric -1.1126755152085162e+20
# fold 4 epoch 69 train 0.01 valid 0.011 metric -6.564564309828055e+19
# fold 4 epoch 70 train 0.009 valid 0.016 metric -7.67362409820206e+19
# fold 4 epoch 71 train 0.011 valid 0.012 metric -6.213074287731025e+19
# fold 4 epoch 72 train 0.01 valid 0.011 metric -7.088744670888428e+19
# fold 4 epoch 73 train 0.009 valid 0.008 metric -3.820111623136183e+19
# fold 4 epoch 74 train 0.009 valid 0.01 metric -5.434688208262312e+19
# fold 4 epoch 75 train 0.009 valid 0.011 metric -5.252622407829121e+19
# fold 4 epoch 76 train 0.009 valid 0.01 metric -1.705143087853954e+19
# fold 4 epoch 77 train 0.008 valid 0.008 metric -3.903669582260171e+19
# fold 4 epoch 78 train 0.008 valid 0.009 metric -4.208182390991379e+19
# fold 4 epoch 79 train 0.008 valid 0.008 metric -8.442367942637006e+19
# fold 4 epoch 80 train 0.009 valid 0.008 metric -3.540652813017208e+19
# fold 4 epoch 81 train 0.008 valid 0.008 metric -3.384818299981023e+19
# fold 4 epoch 82 train 0.009 valid 0.008 metric -3.86406035150279e+19
# fold 4 epoch 83 train 0.008 valid 0.009 metric -2.9164731707758633e+19
# fold 4 epoch 84 train 0.008 valid 0.009 metric -5.024730356360616e+19
# fold 4 epoch 85 train 0.007 valid 0.008 metric -1.8027325416093299e+19
# fold 4 epoch 86 train 0.008 valid 0.008 metric -4.816500161431818e+19
# fold 4 epoch 87 train 0.009 valid 0.01 metric -2.6656912927035257e+19
# fold 4 epoch 88 train 0.01 valid 0.009 metric -2.198442600091612e+19
# fold 4 epoch 89 train 0.007 valid 0.008 metric -5.025575201801119e+19
# fold 4 epoch 90 train 0.007 valid 0.008 metric -3.816874497263275e+19
# fold 4 epoch 91 train 0.007 valid 0.007 metric -1.6607227683243639e+19
# fold 4 epoch 92 train 0.008 valid 0.008 metric -1.1883575609585404e+19
# fold 4 epoch 93 train 0.009 valid 0.008 metric -4.441454364374979e+19
# fold 4 epoch 94 train 0.007 valid 0.008 metric -4.084588644329462e+19
# fold 4 epoch 95 train 0.007 valid 0.007 metric -4.6094889652294664e+19
# fold 4 epoch 96 train 0.007 valid 0.007 metric -3.4635718248617378e+19
# fold 4 epoch 97 train 0.007 valid 0.007 metric -1.5361329430647525e+19
# fold 4 epoch 98 train 0.008 valid 0.008 metric -8.112659959074759e+19
# fold 4 epoch 99 train 0.007 valid 0.008 metric -6.512823393764643e+19
# fold 4 epoch 100 train 0.007 valid 0.007 metric -1.986315257343755e+19
# fold 4 epoch 101 train 0.007 valid 0.006 metric -9.43662694586011e+18
# fold 4 epoch 102 train 0.007 valid 0.007 metric -1.654517717211507e+19
# fold 4 epoch 103 train 0.007 valid 0.007 metric -1.2908870308955126e+19
# fold 4 epoch 104 train 0.007 valid 0.009 metric -4.478601300484886e+19
# fold 4 epoch 105 train 0.007 valid 0.007 metric -3.827417669710373e+19
# fold 4 epoch 106 train 0.006 valid 0.006 metric -3.2434650550236365e+19
# fold 4 epoch 107 train 0.006 valid 0.006 metric -1.0082605481215244e+19
# fold 4 epoch 108 train 0.006 valid 0.006 metric -6.447355662121786e+18
# fold 4 epoch 109 train 0.006 valid 0.007 metric -3.340578178040874e+19
# fold 4 epoch 110 train 0.006 valid 0.008 metric -2.520608091768927e+19
# fold 4 epoch 111 train 0.006 valid 0.007 metric -1.6349036583493587e+19
# fold 4 epoch 112 train 0.006 valid 0.007 metric -1.972496755094698e+19
# fold 4 epoch 113 train 0.006 valid 0.007 metric -2.2739484993412235e+19
# fold 4 epoch 114 train 0.006 valid 0.006 metric -1.603081906829351e+19
# fold 4 epoch 115 train 0.006 valid 0.006 metric -5.593355194760149e+18
# fold 4 epoch 116 train 0.006 valid 0.007 metric -1.7017532393369807e+19
# fold 4 epoch 117 train 0.006 valid 0.006 metric -3.782006627450597e+18
# fold 4 epoch 118 train 0.006 valid 0.006 metric -1.3596245225428326e+19
# fold 4 epoch 119 train 0.005 valid 0.006 metric -9.34550252121543e+18
# fold 4 epoch 120 train 0.006 valid 0.007 metric -4.886680109857977e+19
# fold 4 epoch 121 train 0.006 valid 0.006 metric -6.77981504205917e+18
# fold 4 epoch 122 train 0.005 valid 0.006 metric -9.302544572074602e+18
# fold 4 epoch 123 train 0.006 valid 0.008 metric -1.4729573397485386e+19
# fold 4 epoch 124 train 0.006 valid 0.006 metric -3.3836923738486866e+19
# fold 4 epoch 125 train 0.005 valid 0.006 metric -3.431455819579602e+18
# fold 4 epoch 126 train 0.005 valid 0.006 metric -1.4987341280969261e+19
# fold 4 epoch 127 train 0.005 valid 0.006 metric -6.223089354642277e+18
# fold 4 epoch 128 train 0.005 valid 0.006 metric -9.599333003879158e+18
# fold 4 epoch 129 train 0.005 valid 0.006 metric -1.2718826547787645e+19
# fold 4 epoch 130 train 0.005 valid 0.005 metric -1.6098207619265028e+19
# fold 4 epoch 131 train 0.005 valid 0.005 metric -3.1538920551651487e+18
# fold 4 epoch 132 train 0.005 valid 0.005 metric -2.610828679222637e+18
# fold 4 epoch 133 train 0.005 valid 0.005 metric -5.205690652036105e+18
# fold 4 epoch 134 train 0.005 valid 0.006 metric -5.475226061256064e+18
# fold 4 epoch 135 train 0.005 valid 0.005 metric -4.08342798062161e+18
# fold 4 epoch 136 train 0.005 valid 0.005 metric -8.366482668094028e+18
# fold 4 epoch 137 train 0.005 valid 0.007 metric 0.429
# fold 4 epoch 138 train 0.005 valid 0.006 metric -9.863044254222561e+18
# fold 4 epoch 139 train 0.005 valid 0.006 metric -4.746471678779694e+18
# fold 4 epoch 140 train 0.005 valid 0.006 metric -5.915377024250835e+18
# fold 4 epoch 141 train 0.005 valid 0.005 metric -4.921752778270866e+18
# fold 4 epoch 142 train 0.005 valid 0.005 metric -2.2276211924557267e+19
# fold 4 epoch 143 train 0.005 valid 0.006 metric 0.436
# fold 4 epoch 144 train 0.005 valid 0.007 metric -1.700986010158648e+17
# fold 4 epoch 145 train 0.005 valid 0.005 metric -3.612862094880152e+18
# fold 4 epoch 146 train 0.005 valid 0.006 metric -7.86655750349909e+17
# fold 4 epoch 147 train 0.005 valid 0.005 metric -1.2466075235342216e+18
# fold 4 epoch 148 train 0.004 valid 0.005 metric -7.044772467973901e+17
# fold 4 epoch 149 train 0.005 valid 0.006 metric -4.049108336090677e+17
# fold 4 epoch 150 train 0.005 valid 0.005 metric -3.929476036349449e+18
# fold 4 epoch 151 train 0.004 valid 0.005 metric -2.4377399759843155e+17
# fold 4 epoch 152 train 0.004 valid 0.005 metric -3.715791303206717e+17
# fold 4 epoch 153 train 0.004 valid 0.006 metric -2.3862502384746614e+17
# fold 4 epoch 154 train 0.005 valid 0.005 metric 0.48
# fold 4 epoch 155 train 0.004 valid 0.005 metric -1.3423402544883766e+18
# fold 4 epoch 156 train 0.004 valid 0.005 metric -3.148479898014488e+18
# fold 4 epoch 157 train 0.004 valid 0.005 metric 0.496
# fold 4 epoch 158 train 0.004 valid 0.005 metric 0.481
# fold 4 epoch 159 train 0.004 valid 0.005 metric 0.5
# fold 4 epoch 160 train 0.004 valid 0.005 metric -8.942413393794707e+17
# fold 4 epoch 161 train 0.004 valid 0.005 metric -4.1283086500057114e+17
# fold 4 epoch 162 train 0.004 valid 0.005 metric 0.508
# fold 4 epoch 163 train 0.004 valid 0.005 metric 0.511
# fold 4 epoch 164 train 0.004 valid 0.005 metric -8404612807171582.0
# fold 4 epoch 165 train 0.004 valid 0.005 metric 0.484
# fold 4 epoch 166 train 0.004 valid 0.005 metric 0.51
# fold 4 epoch 167 train 0.004 valid 0.005 metric 0.476
# fold 4 epoch 168 train 0.004 valid 0.005 metric 0.496
# fold 4 epoch 169 train 0.004 valid 0.005 metric 0.533
# fold 4 epoch 170 train 0.004 valid 0.005 metric 0.529
# fold 4 epoch 171 train 0.004 valid 0.005 metric 0.52
# fold 4 epoch 172 train 0.004 valid 0.005 metric 0.512
# fold 4 epoch 173 train 0.004 valid 0.005 metric 0.52
# fold 4 epoch 174 train 0.004 valid 0.005 metric 0.532
# fold 4 epoch 175 train 0.004 valid 0.005 metric 0.508
# fold 4 epoch 176 train 0.004 valid 0.005 metric 0.527
# fold 4 epoch 177 train 0.004 valid 0.005 metric 0.535
# fold 4 epoch 178 train 0.004 valid 0.005 metric 0.528
# fold 4 epoch 179 train 0.004 valid 0.005 metric 0.535
# fold 4 epoch 180 train 0.004 valid 0.005 metric 0.537
# fold 4 epoch 181 train 0.004 valid 0.005 metric 0.525
# fold 4 epoch 182 train 0.004 valid 0.004 metric 0.526
# fold 4 epoch 183 train 0.004 valid 0.005 metric 0.537
# fold 4 epoch 184 train 0.004 valid 0.005 metric 0.535
# fold 4 epoch 185 train 0.004 valid 0.005 metric 0.535
# fold 4 epoch 186 train 0.004 valid 0.005 metric 0.536
# fold 4 epoch 187 train 0.004 valid 0.005 metric 0.537
# fold 4 epoch 188 train 0.004 valid 0.005 metric 0.539
# fold 4 epoch 189 train 0.004 valid 0.005 metric 0.54
# fold 4 epoch 190 train 0.004 valid 0.005 metric 0.536
# fold 4 epoch 191 train 0.004 valid 0.005 metric 0.543
# fold 4 epoch 192 train 0.004 valid 0.005 metric 0.541
# fold 4 epoch 193 train 0.004 valid 0.005 metric 0.539
# fold 4 epoch 194 train 0.004 valid 0.005 metric 0.541
# fold 4 epoch 195 train 0.004 valid 0.005 metric 0.541
# fold 4 epoch 196 train 0.004 valid 0.005 metric 0.542
# fold 4 epoch 197 train 0.004 valid 0.005 metric 0.541
# fold 4 epoch 198 train 0.004 valid 0.005 metric 0.541
# fold 4 epoch 199 train 0.004 valid 0.005 metric 0.541

# %%
ariel_score(        
            train_labels.values,
            np.concatenate([oof_pred.clip(0), oof_sigmas.clip(0)], axis=1), 
            train_labels.values.mean(),
            train_labels.values.std(),
            sigma_true=1e-5)
# Out:
# 0.4022801974296382

# %%
xs,ys = [], []
for i in range(200):
    xs.append(i/100.0)
    ys.append(ariel_score(        
            train_labels.values,
            np.concatenate([oof_pred.clip(0), oof_sigmas.clip(0) * (i / 100.0)], axis=1), 
            train_labels.values.mean(),
            train_labels.values.std(),
            sigma_true=1e-5))
plt.plot(xs, np.array(ys).clip(0))

# %%
np.save('purple_hat_oof_pred.npy', oof_pred)
np.save('purple_hat_oof_sigmas.npy', oof_sigmas)

# %% [markdown]
# ## Inteference

# %%
test = pre_test.copy()
for i in range(len(pre_test)):
    p1,p2 = phase_detector(pre_test[i,:,1:].mean(axis=1))
    test[i] = (test[i] - pre_test[i,p1:p2].mean(axis=0)) / pre_test[i,list(range(p1-20)) + list(range(p2+20,187))].mean(axis=0) * 1000.0
test_tensor = torch.tensor(test, dtype=torch.float32).unsqueeze(1) 
test_tensor = test_tensor.to(device)
with torch.no_grad(): 
    model.eval()
    pred = model(test_tensor)
output_a = pred[:,1::3] # differ to quantile 0, 1, 2

# %%
output_numpy = output_a.cpu().detach().numpy()

# %%
sample_sub = pd.read_csv("/kaggle/input/ariel-data-challenge-2024/sample_submission.csv")
sub = sample_sub.copy()
sub.iloc[:,1:284] = output_numpy

# %% [markdown]
# ## Sigma

# %%
# model.eval()
# running_vloss = 0
# preds = np.zeros((1, 283))
# sigmas = np.zeros((1, 283))
# v_offset = 0
# with torch.no_grad():        
#     vinputs= test_tensor
#     vinputs= vinputs.to(device) 

#     voutputs = model(vinputs).reshape((vinputs.shape[0], 283, 3))
#     preds[v_offset:v_offset+len(vinputs)] = voutputs[:, :, 1].detach().cpu().numpy()
#     sigmas[v_offset:v_offset+len(vinputs)] = voutputs[:, :, 2].detach().cpu().numpy() - voutputs[:, :, 0].detach().cpu().numpy()

# %%
sub.iloc[:,284:] = 0.00025252799786631074
sub.to_csv("submission.csv", index = False)

# %%
sub
# Out:
#    planet_id      wl_1     wl_2      wl_3      wl_4      wl_5      wl_6  \
# 0  499191466  0.002706  0.00273  0.002726  0.002724  0.002726  0.002719
#
#       wl_7      wl_8      wl_9  ...  sigma_274  sigma_275  sigma_276  \
# 0  0.00272  0.002723  0.002722  ...   0.000253   0.000253   0.000253
#
#    sigma_277  sigma_278  sigma_279  sigma_280  sigma_281  sigma_282  sigma_283
# 0   0.000253   0.000253   0.000253   0.000253   0.000253   0.000253   0.000253
#
# [1 rows x 567 columns]
